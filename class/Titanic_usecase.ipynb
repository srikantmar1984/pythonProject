# %% [markdown]
# #### learnbay12thjuly@gmail.com

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# using drop
df.drop(columns = ['alive','embarked'], inplace = True)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare   class    who  \
# 0           0       3    male  22.0      1      0   7.2500   Third    man
# 1           1       1  female  38.0      1      0  71.2833   First  woman
# 2           1       3  female  26.0      0      0   7.9250   Third  woman
# 3           1       1  female  35.0      1      0  53.1000   First  woman
# 4           0       3    male  35.0      0      0   8.0500   Third    man
# ..        ...     ...     ...   ...    ...    ...      ...     ...    ...
# 886         0       2    male  27.0      0      0  13.0000  Second    man
# 887         1       1  female  19.0      0      0  30.0000   First  woman
# 888         0       3  female   NaN      1      2  23.4500   Third  woman
# 889         1       1    male  26.0      0      0  30.0000   First    man
# 890         0       3    male  32.0      0      0   7.7500   Third    man
#
#      adult_male deck  embark_town  alone
# ...

# %%
# using del

del [df['adult_male'] , df['class'] , df['who']]

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# deck           688
# embark_town      2
# alone            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   deck         203 non-null    category
#  8   embark_town  889 non-null    object
#  9   alone        891 non-null    bool
# dtypes: bool(1), category(1), float64(2), int64(4), object(2)
# memory usage: 57.9+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.fillna({'age': df['age'].mean(),
            'deck': df['deck'].mode()[0],
            'embark_town': df['embark_town'].mode()[0]} , inplace = True)

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# deck           0
# embark_town    0
# alone          0
# dtype: int64

# %%
df.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             89
# sibsp            7
# parch            7
# fare           248
# deck             7
# embark_town      3
# alone            2
# dtype: int64

# %%
df
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare deck  \
# 0           0       3    male  22.000000      1      0   7.2500    C
# 1           1       1  female  38.000000      1      0  71.2833    C
# 2           1       3  female  26.000000      0      0   7.9250    C
# 3           1       1  female  35.000000      1      0  53.1000    C
# 4           0       3    male  35.000000      0      0   8.0500    C
# ..        ...     ...     ...        ...    ...    ...      ...  ...
# 886         0       2    male  27.000000      0      0  13.0000    C
# 887         1       1  female  19.000000      0      0  30.0000    B
# 888         0       3  female  29.699118      1      2  23.4500    C
# 889         1       1    male  26.000000      0      0  30.0000    C
# 890         0       3    male  32.000000      0      0   7.7500    C
#
#      embark_town  alone
# 0    Southampton  False
# 1      Cherbourg  False
# 2    Southampton   True
# 3    Southampton  False
# ...

# %%
# If you want to save the file which you have worked on
df.to_csv('data_titanic.csv')

# %%
df
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare deck  \
# 0           0       3    male  22.000000      1      0   7.2500    C
# 1           1       1  female  38.000000      1      0  71.2833    C
# 2           1       3  female  26.000000      0      0   7.9250    C
# 3           1       1  female  35.000000      1      0  53.1000    C
# 4           0       3    male  35.000000      0      0   8.0500    C
# ..        ...     ...     ...        ...    ...    ...      ...  ...
# 886         0       2    male  27.000000      0      0  13.0000    C
# 887         1       1  female  19.000000      0      0  30.0000    B
# 888         0       3  female  29.699118      1      2  23.4500    C
# 889         1       1    male  26.000000      0      0  30.0000    C
# 890         0       3    male  32.000000      0      0   7.7500    C
#
#      embark_town  alone
# 0    Southampton  False
# 1      Cherbourg  False
# 2    Southampton   True
# 3    Southampton  False
# ...

# %%
# Box plot

plt.boxplot(df['fare'])
plt.show()

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.002015    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   29.699118    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# 

sns.displot(df['fare'] , kde = True)

# %%
# z-score
mean_of_fare = np.mean(df['fare'])
std_of_sales = np.std(df['fare'])

threshold = 3
outlier = []


for i in df['fare']:
    z = (i-mean_of_fare) / (std_of_sales)
    if z > threshold:
        outlier.append(i)

        
print('Total no of outliers in your dataset are : ' , len(outlier))
print('Maximum fare outlier : ' , max(outlier))
print('Minimum fare outlier : ' , min(outlier))
# Out:
# Total no of outliers in your dataset are :  20
# Maximum fare outlier :  512.3292
# Minimum fare outlier :  211.3375

# %%
sns.displot(x = outlier , bins = 20).set(title = 'Outlier distribution of fare')

# %%
to_drop = df.loc[df['fare'] > min(outlier)]
print(len(to_drop))
print(to_drop)
# Out:
# 17
#      survived  pclass     sex        age  sibsp  parch      fare deck  \
# 27          0       1    male  19.000000      3      2  263.0000    C
# 88          1       1  female  23.000000      3      2  263.0000    C
# 118         0       1    male  24.000000      0      1  247.5208    B
# 258         1       1  female  35.000000      0      0  512.3292    C
# 299         1       1  female  50.000000      0      1  247.5208    B
# 311         1       1  female  18.000000      2      2  262.3750    B
# 341         1       1  female  24.000000      3      2  263.0000    C
# 377         0       1    male  27.000000      0      2  211.5000    C
# 380         1       1  female  42.000000      0      0  227.5250    C
# 438         0       1    male  64.000000      1      4  263.0000    C
# 527         0       1    male  29.699118      0      0  221.7792    C
# 557         0       1    male  29.699118      0      0  227.5250    C
# ...

# %%
to_drop
# Out:
#      survived  pclass     sex        age  sibsp  parch      fare deck  \
# 27          0       1    male  19.000000      3      2  263.0000    C
# 88          1       1  female  23.000000      3      2  263.0000    C
# 118         0       1    male  24.000000      0      1  247.5208    B
# 258         1       1  female  35.000000      0      0  512.3292    C
# 299         1       1  female  50.000000      0      1  247.5208    B
# 311         1       1  female  18.000000      2      2  262.3750    B
# 341         1       1  female  24.000000      3      2  263.0000    C
# 377         0       1    male  27.000000      0      2  211.5000    C
# 380         1       1  female  42.000000      0      0  227.5250    C
# 438         0       1    male  64.000000      1      4  263.0000    C
# 527         0       1    male  29.699118      0      0  221.7792    C
# 557         0       1    male  29.699118      0      0  227.5250    C
# ...

# %%
df.drop(to_drop.index , inplace = True)
# df.drop(to_drop , inplace = True)
# df.drop(df.loc[df['fare'] > min(outlier)].index , inplace = True)

# %%
#IQR
# Q1,Q3 = df.fare.quantile([0.25,0.75])
# print(Q1)
# print(Q3)
# IQR = Q3 - Q1
# print(IQR)
# lower_bound = Q1 - 1.5*(IQR)
# upper_bound = Q3 + 1.5*(IQR)
# print(lower_bound)
# print(upper_bound)

# df = df[(df.fare > lower_bound) & (df.fare < upper_bound)]
# df

# %%
len(df)
# Out:
# 874

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 874 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     874 non-null    int64
#  1   pclass       874 non-null    int64
#  2   sex          874 non-null    object
#  3   age          874 non-null    float64
#  4   sibsp        874 non-null    int64
#  5   parch        874 non-null    int64
#  6   fare         874 non-null    float64
#  7   deck         874 non-null    category
#  8   embark_town  874 non-null    object
#  9   alone        874 non-null    bool
# dtypes: bool(1), category(1), float64(2), int64(4), object(2)
# memory usage: 63.5+ KB

# %%
sns.displot(df['fare'] , kde = True)

# %%
df.drop(df.loc[df['fare'] >50].index , inplace = True)

# %%
df
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare deck  \
# 0           0       3    male  22.000000      1      0   7.2500    C
# 2           1       3  female  26.000000      0      0   7.9250    C
# 4           0       3    male  35.000000      0      0   8.0500    C
# 5           0       3    male  29.699118      0      0   8.4583    C
# 7           0       3    male   2.000000      3      1  21.0750    C
# ..        ...     ...     ...        ...    ...    ...      ...  ...
# 886         0       2    male  27.000000      0      0  13.0000    C
# 887         1       1  female  19.000000      0      0  30.0000    B
# 888         0       3  female  29.699118      1      2  23.4500    C
# 889         1       1    male  26.000000      0      0  30.0000    C
# 890         0       3    male  32.000000      0      0   7.7500    C
#
#      embark_town  alone
# 0    Southampton  False
# 2    Southampton   True
# 4    Southampton   True
# 5     Queenstown   True
# ...

# %%
sns.displot(df['fare'] , kde = True)

# %%
# replace fare where above 20 to 10

df_1 = df[df['fare'] > 20]
for d in df_1.fare:
    df['fare'].replace(d,10,inplace=True)

# %%
df['fare'].unique()
# Out:
# array([ 7.25  ,  7.925 ,  8.05  ,  8.4583, 10.    , 11.1333, 16.7   ,
#         7.8542, 16.    , 13.    , 18.    ,  7.225 ,  8.0292,  7.8792,
#         7.8958,  7.75  , 10.5   ,  7.2292, 11.2417,  9.475 , 15.5   ,
#        17.8   ,  7.8   , 15.2458,  8.1583,  8.6625, 14.4542,  7.65  ,
#        12.475 ,  9.    ,  9.5   ,  7.7875, 15.85  ,  8.6542,  7.775 ,
#         9.825 , 14.4583,  7.1417,  6.975 ,  7.05  , 14.5   , 15.0458,
#         9.2167,  6.75  , 11.5   ,  7.7958, 12.525 ,  7.3125,  7.7333,
#        16.1   , 15.75  ,  0.    , 15.05  ,  8.4042,  6.4958, 10.4625,
#        18.7875,  9.35  , 13.5   ,  7.55  , 12.275 ,  7.125 , 19.5   ,
#        12.875 ,  8.85  , 12.35  , 14.    ,  6.2375, 15.9   ,  9.225 ,
#         4.0125, 15.7417,  7.7292, 12.    , 12.65  , 18.75  ,  6.8583,
#         7.875 , 14.4   ,  8.1125, 19.2583, 19.9667,  7.725 , 13.7917,
#         9.8375,  7.0458,  7.5208, 12.2875,  9.5875, 15.1   ,  7.6292,
# ...

# %%
sns.displot(df['fare'] , kde = True , bins = 50)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 731 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     731 non-null    int64
#  1   pclass       731 non-null    int64
#  2   sex          731 non-null    object
#  3   age          731 non-null    float64
#  4   sibsp        731 non-null    int64
#  5   parch        731 non-null    int64
#  6   fare         731 non-null    float64
#  7   deck         731 non-null    category
#  8   embark_town  731 non-null    object
#  9   alone        731 non-null    bool
# dtypes: bool(1), category(1), float64(2), int64(4), object(2)
# memory usage: 53.2+ KB

# %%
df['deck'].unique()
# Out:
# ['C', 'G', 'D', 'A', 'F', 'E', 'B']
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
df['embark_town'].unique()
# Southampton - 1
# Queenstown - 2
# Cherbourg - 3
# Out:
# array(['Southampton', 'Queenstown', 'Cherbourg'], dtype=object)

# %%
df['alone'].unique() # ----true-1 and false 0
# Out:
# array([False,  True])

# %%
'''
df['embark_town'].loc[df['embark_town'] == 'Southampton'] = 1
df['embark_town'].loc[df['embark_town'] == 'Queenstown'] = 2
df['embark_town'].loc[df['embark_town'] == 'Cherbourg'] = 3

'''

# %%
df.replace(['Southampton','Queenstown','Cherbourg'],[1,2,3] , inplace = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 731 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     731 non-null    int64
#  1   pclass       731 non-null    int64
#  2   sex          731 non-null    object
#  3   age          731 non-null    float64
#  4   sibsp        731 non-null    int64
#  5   parch        731 non-null    int64
#  6   fare         731 non-null    float64
#  7   deck         731 non-null    category
#  8   embark_town  731 non-null    int64
#  9   alone        731 non-null    bool
# dtypes: bool(1), category(1), float64(2), int64(5), object(1)
# memory usage: 53.2+ KB

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()


df['alone']  = label_encoder.fit_transform(df['alone'])
df['deck']  = label_encoder.fit_transform(df['deck'])
df['sex']  = label_encoder.fit_transform(df['sex'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 731 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     731 non-null    int64
#  1   pclass       731 non-null    int64
#  2   sex          731 non-null    int32
#  3   age          731 non-null    float64
#  4   sibsp        731 non-null    int64
#  5   parch        731 non-null    int64
#  6   fare         731 non-null    float64
#  7   deck         731 non-null    int64
#  8   embark_town  731 non-null    int64
#  9   alone        731 non-null    int64
# dtypes: float64(2), int32(1), int64(7)
# memory usage: 60.0 KB

# %%
df['deck'].unique()
# Out:
# array([2, 6, 3, 0, 5, 4, 1])

# %%
df['sex'].unique()
# Out:
# array([1, 0])

# %%
sns.countplot(df['deck'])
# Out:
# C:\Users\MIT\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='deck', ylabel='count'>

# %%
x=list(map(lambda i: int(i), list(df['alone'])))
df['alone']=x
df
# Out:
#      survived  pclass  sex        age  sibsp  parch     fare  deck  \
# 0           0       3    1  22.000000      1      0   7.2500     2
# 2           1       3    0  26.000000      0      0   7.9250     2
# 4           0       3    1  35.000000      0      0   8.0500     2
# 5           0       3    1  29.699118      0      0   8.4583     2
# 7           0       3    1   2.000000      3      1  10.0000     2
# ..        ...     ...  ...        ...    ...    ...      ...   ...
# 886         0       2    1  27.000000      0      0  13.0000     2
# 887         1       1    0  19.000000      0      0  10.0000     1
# 888         0       3    0  29.699118      1      2  10.0000     2
# 889         1       1    1  26.000000      0      0  10.0000     2
# 890         0       3    1  32.000000      0      0   7.7500     2
#
#      embark_town  alone
# 0              1      0
# 2              1      1
# 4              1      1
# 5              2      1
# 7              1      0
# ...

# %%
plt.figure(figsize= (10,10))
sns.heatmap(df.corr() , annot= True)
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#              survived    pclass       sex       age     sibsp     parch  \
# survived     1.000000 -0.205934 -0.498967 -0.142327 -0.018485  0.099386
# pclass      -0.205934  1.000000 -0.020900 -0.325065  0.162670  0.090337
# sex         -0.498967 -0.020900  1.000000  0.138596 -0.141420 -0.289399
# age         -0.142327 -0.325065  0.138596  1.000000 -0.367061 -0.221924
# sibsp       -0.018485  0.162670 -0.141420 -0.367061  1.000000  0.424381
# parch        0.099386  0.090337 -0.289399 -0.221924  0.424381  1.000000
# fare         0.203049 -0.110781 -0.233566 -0.075193  0.195751  0.175794
# deck         0.130213  0.019829 -0.097028 -0.099110 -0.003905  0.061085
# embark_town  0.108224 -0.005928 -0.069957 -0.034161 -0.052738 -0.028777
# alone       -0.165675 -0.101851  0.330347  0.319954 -0.668802 -0.615900
#
#                  fare      deck  embark_town     alone
# survived     0.203049  0.130213     0.108224 -0.165675
# pclass      -0.110781  0.019829    -0.005928 -0.101851
# ...
