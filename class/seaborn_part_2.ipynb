# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install pandas-profiling
# Out:
# ...
#   Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# ...
#   Using cached pydantic-1.9.2-cp39-cp39-win_amd64.whl (2.0 MB)
# ...
#   Using cached htmlmin-0.1.12-py3-none-any.whl
# ...
#   Using cached missingno-0.5.1-py3-none-any.whl (8.7 kB)
# ...
#   Using cached phik-0.12.2-cp39-cp39-win_amd64.whl (685 kB)
# ...
#   Using cached ImageHash-4.2.1-py2.py3-none-any.whl
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
days=[1,2,3,4,5,6,7] # weekdays
max_t=[50,51,52,48,47,49,46] # max temp recorder at that day
min_t=[43,42,40,44,45,35,37] # min temp
avg_t=[45,48,48,46,40,42,41] # avg temp

# %%
plt.plot(days, max_t, '-', min_t, '--', avg_t, ':')
plt.xlabel('days')
plt.ylabel('temp')
plt.title('overall temp vs days')
# Out:
# Text(0.5, 1.0, 'overall temp vs days')

# %%
#  

tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Which among the people paid more tips

# smoker 
# not a smoker

# %%
sns.relplot(x = 'total_bill' , y ='tip' , data= tips)

# %%
sns.relplot(x = 'total_bill' , y ='tip' , data= tips , col = 'smoker')

# %%
sns.relplot(x = 'total_bill' , y ='tip' , hue = 'smoker',data= tips)

# %%
sns.relplot(x = tips['total_bill'] , y =tips['tip'] )

# %%
sns.relplot(x = 'total_bill' , y ='tip' , hue = 'smoker' , col= 'smoker',data= tips)

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x = 'sepal_length' , y = 'petal_length' , data =iris )
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.catplot(x = 'day' , y ='total_bill' ,data= tips)

# %%
sns.catplot(x = 'day' , y ='total_bill' ,data= tips , jitter = False)

# %%
sns.catplot(x = 'day' , y ='total_bill' ,data= tips , kind = 'swarm')

# %%
sns.catplot(x = 'day' , y ='total_bill' ,data= tips , kind = 'box')

# %%
sns.catplot(x = 'day' , y ='total_bill' ,data= tips , kind = 'violin')

# %%
x = np.random.randn(100)
sns.displot(x)

# %%
x = np.random.randn(100)
sns.displot(x , kde = True)

# %%
sns.displot(tips['total_bill'] , kde = True)

# %%
sns.displot(tips['total_bill'])

# %%
sns.scatterplot(x = 'total_bill' , y = 'tip' , data = tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.jointplot(x = 'total_bill' , y = 'tip' , data = tips , marginal_ticks=True )

# %%
sns.pairplot(tips)

# %%
sns.pairplot(iris)

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
# Heat map
plt.figure(figsize = (5,5))
sns.heatmap(tips.corr() , annot = True)
# Out:
# <AxesSubplot:>

# %%
# Heat map
plt.figure(figsize = (5,5))
sns.heatmap(tips.corr() )
# Out:
# <AxesSubplot:>

# %%
# Heat map
plt.figure(figsize = (5,5))
sns.heatmap(iris.corr() , annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Titanic usecase

# %%
data = sns.load_dataset('titanic')
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# COLUMNS TO DEL

1. alive
2. embarked
3. adult_male
4. class
5. who

# %%
# using drop
data.drop(columns = ['alive','embarked'], inplace = True)
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare   class    who  \
# 0           0       3    male  22.0      1      0   7.2500   Third    man
# 1           1       1  female  38.0      1      0  71.2833   First  woman
# 2           1       3  female  26.0      0      0   7.9250   Third  woman
# 3           1       1  female  35.0      1      0  53.1000   First  woman
# 4           0       3    male  35.0      0      0   8.0500   Third    man
# ..        ...     ...     ...   ...    ...    ...      ...     ...    ...
# 886         0       2    male  27.0      0      0  13.0000  Second    man
# 887         1       1  female  19.0      0      0  30.0000   First  woman
# 888         0       3  female   NaN      1      2  23.4500   Third  woman
# 889         1       1    male  26.0      0      0  30.0000   First    man
# 890         0       3    male  32.0      0      0   7.7500   Third    man
#
#      adult_male deck  embark_town  alone
# ...

# %%
# using del

del [data['adult_male'] , data['class'] , data['who']]

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare deck  embark_town  \
# 0           0       3    male  22.0      1      0   7.2500  NaN  Southampton
# 1           1       1  female  38.0      1      0  71.2833    C    Cherbourg
# 2           1       3  female  26.0      0      0   7.9250  NaN  Southampton
# 3           1       1  female  35.0      1      0  53.1000    C  Southampton
# 4           0       3    male  35.0      0      0   8.0500  NaN  Southampton
# ..        ...     ...     ...   ...    ...    ...      ...  ...          ...
# 886         0       2    male  27.0      0      0  13.0000  NaN  Southampton
# 887         1       1  female  19.0      0      0  30.0000    B  Southampton
# 888         0       3  female   NaN      1      2  23.4500  NaN  Southampton
# 889         1       1    male  26.0      0      0  30.0000    C    Cherbourg
# 890         0       3    male  32.0      0      0   7.7500  NaN   Queenstown
#
#      alone
# 0    False
# 1    False
# ...

# %%
(data.isnull().sum())/len(data['survived'])*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# deck           77.216611
# embark_town     0.224467
# alone           0.000000
# dtype: float64

# %%
perc=data. isnull(). sum() * 100 / len(data)
perc
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# deck           77.216611
# embark_town     0.224467
# alone           0.000000
# dtype: float64

# %%
data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# deck           688
# embark_town      2
# alone            0
# dtype: int64

# %%
# fil
1. age            177 with median
2. deck           688 with mode 
3. embark_town      2 wih mode

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   deck         203 non-null    category
#  8   embark_town  889 non-null    object
#  9   alone        891 non-null    bool
# dtypes: bool(1), category(1), float64(2), int64(4), object(2)
# memory usage: 57.9+ KB

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data.fillna({'age': data['age'].mean(),
            'deck': data['deck'].mode()[0],
            'embark_town': data['embark_town'].mode()[0]} , inplace = True)

# %%
data.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# deck           0
# embark_town    0
# alone          0
# dtype: int64

# %%
data.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             89
# sibsp            7
# parch            7
# fare           248
# deck             7
# embark_town      3
# alone            2
# dtype: int64

# %%
data['embark_town'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown'], dtype=object)

# %%
data['parch'].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6], dtype=int64)

# %%
data['deck'].unique()
# Out:
# ['C', 'E', 'G', 'D', 'A', 'B', 'F']
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %% [markdown]
# # Data Visualization

# %%
data
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare deck  \
# 0           0       3    male  22.000000      1      0   7.2500    C
# 1           1       1  female  38.000000      1      0  71.2833    C
# 2           1       3  female  26.000000      0      0   7.9250    C
# 3           1       1  female  35.000000      1      0  53.1000    C
# 4           0       3    male  35.000000      0      0   8.0500    C
# ..        ...     ...     ...        ...    ...    ...      ...  ...
# 886         0       2    male  27.000000      0      0  13.0000    C
# 887         1       1  female  19.000000      0      0  30.0000    B
# 888         0       3  female  29.699118      1      2  23.4500    C
# 889         1       1    male  26.000000      0      0  30.0000    C
# 890         0       3    male  32.000000      0      0   7.7500    C
#
#      embark_town  alone
# 0    Southampton  False
# 1      Cherbourg  False
# 2    Southampton   True
# 3    Southampton  False
# ...

# %%
sns.barplot(x= 'sex' , y = 'survived' , data = data)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %%
sns.countplot(data['sex'])
# Out:
# C:\Users\MIT\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(data['pclass'])
# Out:
# C:\Users\MIT\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %%
sns.barplot(y = 'survived' , x = 'pclass' , data = data)
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='survived'>

# %%
# displot 
sns.displot(data['fare'] , kde = True)

# %% [markdown]
# # box plot

# %%
# fare
# matplotlib

# %%
sns.catplot(x='fare',y='sex',data=data,  kind='box')
